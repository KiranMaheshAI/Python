# %% [markdown]
# ### Linked List

# %%
# Middle of LinkedList


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        newNode = Node(data)
        if self.head is None:
            self.head = newNode
        else:
            current = self.head
            while current.next is not None:
                current = current.next
            current.next = newNode

    def print(self):
        current = self.head
        while current is not None:
            print(current.data, end=" -> ")
            current = current.next
        print("None")


ll = LinkedList()
ll.insert(1)
ll.insert(2)
ll.insert(3)
ll.insert(4)
ll.insert(5)
ll.print()
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 -> None

# %%
# middel of Linked List
def middleOfLinkedList(head):
    slow = head
    fast = head
    while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next
    return slow

def lengthOfLinkedList(head):
    length = 0
    current = head
    while current is not None:
        length += 1
        current = current.next
    return length

def middleOfLinkedList(head):
    if head is None or head.next is None:
        return head
    length = lengthOfLinkedList(head)
    mid = length // 2
    current = head
    for i in range(mid):
        current = current.next
    return current

# %%
ll3 = LinkedList()
ll3.insert(3)
ll3.insert(8)
ll3.insert(10)
ll3.insert(15)
ll3.insert(20)
ll3.print()
# Out:
# 3 -> 8 -> 10 -> 15 -> 20 -> None

# %%
ll4 = LinkedList()
ll4.insert(1)
ll4.insert(2)
ll4.insert(5)
ll4.insert(6)
ll4.insert(12)

ll4.insert(20)
ll4.print()
# Out:
# 1 -> 2 -> 5 -> 6 -> 12 -> 20 -> None

# %%
def mergeTwoSortedLists(head1, head2):
    if head1 is None:
        return head2
    if head2 is None:
        return head1
    finalhead = Node(0)
    tail = finalhead
    while head1 is not None and head2 is not None:
        if head1.data < head2.data:
            tail.next = head1
            head1 = head1.next
        else:
            tail.next = head2
            head2 = head2.next
        tail = tail.next
    if head1 is not None:
        tail.next = head1
    if head2 is not None:
        tail.next = head2
    return finalhead.next


head2 = mergeTwoSortedLists(ll3.head, ll4.head)
ll5 = LinkedList()
ll5.head = head2
ll5.print()

# %%
ll6 = LinkedList()
ll6.insert(1)
ll6.insert(2)
ll6.insert(5)
ll6.insert(6)
ll6.insert(12)
ll6.print()
# Out:
# 1 -> 2 -> 5 -> 6 -> 12 -> None

# %%
# Reverse Linked List Iteratively
def reverseLinkedList(head):
    previous = None
    current = head
    while current is not None:
        next = current.next
        current.next = previous
        previous = current
        current = next
    return previous

ll7 = LinkedList()
ll7.insert(1)

# %%
# Reverse Linked List
def reverse_linked_list(head):
    if head is None or head.next is None:
        return head
    smallLinkedListHead = reverse_linked_list(head.next)
    newHead = smallLinkedListHead
    while(newHead.next is not None):
        newHead = newHead.next
    newHead.next = head
    head.next = None
    return smallLinkedListHead

# %%
# Reverse Linked List with tail
def reverse_linked_list_with_tail(head):
    if head is None or head.next is None:
        return head, head
    smallLinkedListHead, smallLinkedListTail = reverse_linked_list_with_tail(head.next)
    smallLinkedListTail.next = head
    head.next = None
    return smallLinkedListHead, head

ll8 = LinkedList()
ll8.insert(1)
ll8.insert(2)
ll8.insert(3)
ll8.insert(4)
ll8.insert(5)
ll8.print()
reversed_head, reversed_tail = reverse_linked_list_with_tail(ll8.head)
ll9 = LinkedList()
ll9.head = reversed_head
ll9.print()

# Reverse Linked List in groups of k
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 -> None
# 5 -> 4 -> 3 -> 2 -> 1 -> None

# %%
def reverse_linked_list_better(head):
    if head is None or head.next is None:
        return head
    smallLinkedListHead = reverse_linked_list_better(head.next)
    tailOfReversedList = head.next
    tailOfReversedList.next = head
    head.next = None
    return smallLinkedListHead

# %%
# Merge sort using Linked List
def middleOfLinkedList(head):
    slow = head
    fast = head
    while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next
    slow.next = None
    return head, slow

def mergeSort(head):
    if head is None:
        return
    start, middle = middleOfLinkedList(head)
    ll1 = mergeSort(start)
    ll2 = mergeSort(middle)
    merge(ll1, ll2)

def merge(ll1, ll2):
    if ll1 is None:
        return ll2
    elif ll2 is None:
        return ll1
    
    finalLinkedList = None
    finalLinkedHead = None
    while (ll1.next is None or ll2.next is None):
        if ll1.data < ll2.data:
            if finalLinkedList is None:
                finalLinkedList = Node(ll1.data)
                finalLinkedHead = Node(ll1.data)
            finalLinkedList.next = Node(ll1.data)
            ll1 = ll1.next
        else:
            if finalLinkedList is None:
                finalLinkedList = Node(ll2.data)
                finalLinkedHead = Node(ll2.data)
            finalLinkedList = Node(ll2.data)
            ll2 = ll2.next
    while (ll2.next is None):
        finalLinkedList.next = Node(ll2.data)
        ll2 = ll2.next
    while (ll1.next is None):
        finalLinkedList.next = Node(ll1.data)
        ll1 = ll1.next
    return finalLinkedHead

# %% [markdown]
# ### Template 1: Finding the Middle

# %%
def find_middle(head):
    slow = head
    fast = head

    # Move until fast reaches the end
    while fast is not None and fast.next is not None:
        slow = slow.next          # move slow by 1
        fast = fast.next.next     # move fast by 2

    return slow

# %% [markdown]
# ### Template 2: Cycle Detection (Floyd's Algorithm)

# %%
def has_cycle(head) -> bool:
    slow = head
    fast = head

    while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next

        # If they meet, there's a cycle
        if slow is fast:
            return True

    # Fast reached the end, no cycle
    return False

# %% [markdown]
# ### Template 3: Finding Cycle Start

# %%
def find_cycle_start(head):
    slow = head
    fast = head

    # Phase 1: detect cycle and find meeting point
    while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next.next

        if slow is fast:
            # Phase 2: find cycle start
            pointer = head
            while pointer is not slow:
                pointer = pointer.next
                slow = slow.next
            return slow  # cycle start

    return None  # no cycle
